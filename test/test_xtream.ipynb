# %% [markdown]
# see info:    http://tvmate.icu:8080/player_api.php?username=69NpyV&password=884735
#
# see streams: http://tvmate.icu:8080/player_api.php?username=69NpyV&password=884735&action=get_live_streams
#
# http://supersonictv.live:8080/player_api.php?username=006779&password=439866&action=get_live_streams

# %%
import requests

def filter(BASE_URL, USERNAME, PASSWORD, field, value):
    params = {
        "username": USERNAME,
        "password": PASSWORD,
        "action": "get_live_streams"
    }
    headers = {
        "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36"
    }
    response = requests.get(BASE_URL + "/player_api.php", params=params, headers=headers, timeout=5)
    response.raise_for_status()
    streams = response.json()
    output_streams = [s for s in streams if value.lower() in str(s.get(field).lower())]
    return output_streams

# %%
filter("http://supersonictv.live:8080", "Norman123", "Norman123", "name", "premier")
# Out:
# [{'num': 6928,
#   'name': '[NL] Film 1 Premiere HD',
#   'stream_type': 'live',
#   'stream_id': 84475,
#   'stream_icon': '',
#   'epg_channel_id': None,
#   'added': '1630188549',
#   'category_id': '32',
#   'custom_sid': '',
#   'tv_archive': 0,
#   'direct_source': '',
#   'tv_archive_duration': 0},
#  {'num': 7173,
#   'name': '[BR] Premiere 2 FHD',
#   'stream_type': 'live',
#   'stream_id': 85062,
#   'stream_icon': '',
#   'epg_channel_id': None,
#   'added': '1630188734',
#   'category_id': '23',
#   'custom_sid': '',
#   'tv_archive': 0,
#   'direct_source': '',
#   'tv_archive_duration': 0},
#  {'num': 7174,
#   'name': '[BR] Premiere 3 FHD',
#   'stream_type': 'live',
#   'stream_id': 85063,
#   'stream_icon': '',
#   'epg_channel_id': None,
#   'added': '1630188734',
#   'category_id': '23',
#   'custom_sid': '',
#   'tv_archive': 0,
#   'direct_source': '',
#   'tv_archive_duration': 0},
#  {'num': 7175,
#   'name': '[BR] Premiere 4 FHD',
#   'stream_type': 'live',
# ...

# %%
filter("http://kstv.us:8080", "4VUyfZBQzk", "95104974615", "name", "Premier")

# %%
filter("http://tvmate.icu:8080", "69NpyV", "884735", "name", "Tennis")
