# %%
import os
from PIL import Image

# Folder containing PNG files (change if needed)
folder_path = "logos"

for filename in os.listdir(folder_path):
    if filename.lower().endswith(".png"):
        file_path = os.path.join(folder_path, filename)
        
        with Image.open(file_path) as img:
            width, height = img.size
            
            # Determine scaling factor so smaller side becomes 150 px
            if width < height:
                scale = 150 / width
            else:
                scale = 150 / height
            
            new_width = int(width * scale)
            new_height = int(height * scale)
            
            resized_img = img.resize((new_width, new_height), Image.LANCZOS)
            
            # Overwrite original image
            resized_img.save(file_path)
            
            print(f"Resized: {filename} -> {new_width}x{new_height}")

print("Done.")
# Out:
# Resized: tennis-channel.png -> 150x222
# Resized: tsn-5.png -> 872x150
# Resized: tsn-2.png -> 872x150
# Resized: laliga.png -> 200x150
# Resized: espn.png -> 152x150
# Resized: tnt-sports-1.png -> 529x150
# Resized: tnt-sports-5.png -> 544x150
# Resized: sky-sports-tennis.png -> 408x150
# Resized: astro-premier-league.png -> 302x150
# Resized: eurosport-2.png -> 1476x150
# Resized: sky-sports-football.png -> 410x150
# Resized: europa-league.png -> 150x213
# Resized: tnt-sports-2.png -> 544x150
# Resized: champions-league.png -> 157x150
# Resized: usa-network.png -> 258x150
# Resized: hub-premier-4.png -> 560x150
# Resized: astro-premier-league-2.png -> 302x150
# Resized: hub-premier-1.png -> 560x150
# Resized: astro-football.png -> 302x150
# Resized: tsn-4.png -> 872x150
# Resized: hub-premier-2.png -> 560x150
# Resized: hub-premier-3.png -> 560x150
# Resized: cbs-sports-network.png -> 564x150
# Resized: premier-league.png -> 356x150
# Resized: serie-a.png -> 150x150
# Resized: eurosport-1.png -> 1476x150
# Resized: tsn-1.png -> 872x150
# Resized: now-sports-pl-1.png -> 667x150
# Resized: now-sports-pl-2.png -> 667x150
# Resized: bein-sports-1.png -> 997x150
# Resized: sky-sports-main-event.png -> 410x150
# Resized: sky-sports-premier-league.png -> 387x150
# Resized: tsn-3.png -> 872x150
# Resized: espn-2.png -> 791x150
# Resized: espn-deportes.png -> 404x150
# Resized: tnt-sports-3.png -> 544x150
# Resized: tudn.png -> 640x150
# Resized: bundesliga.png -> 150x150
# Resized: tnt-sports-4.png -> 544x150
# Resized: soccer.png -> 225x150
# Done.
